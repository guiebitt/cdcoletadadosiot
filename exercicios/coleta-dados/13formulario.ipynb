# %% [markdown]
# # Coleta de dados a partir de requisição de formulário

# %%
import requests
param = {'q': 'reforma da previdência'}
req = requests.get('https://g1.globo.com/busca/', data=param)
print(req.text)
# Out:
# <!DOCTYPE html>
# <html> <head><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0"><meta name="robots" content="noindex,nofollow"><title>Resultado da busca por  | </title><link rel="stylesheet" type="text/css" href="//s.glbimg.com/bu/es/media/green/componentes/header_padrao-v2-2.10.1
# .css" media="screen"><link rel="shortcut icon" href="//thumbor.globoi.com/unsafe/fit-in/600x228/s.glbimg.com/jo/g1/f/original/2018/05/23/favicon-g1.jpeg" type="image/ico"><link rel="stylesheet" href="//s.glbimg.com/gl/ba/css/barra-globocom.min.css" type="text/css"> <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(
#
#       ['_setAccount', 'UA-296593-3'],
#       ['_setDomainName', 'g1.globo.com'],
#
#     ['b._setAccount', 'UA-296593-15'],
#     ['b._setDomainName','.globo.com']
#
#   );
#
#   function getQueryVar(varName){
#     var location = window.location.search || window.location.hash;
# ...
